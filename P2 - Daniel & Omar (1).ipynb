# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 2

# %% [markdown]
# ___
# ## Daniel Castro
#
# ## Omar Dibo Calixto Afrange Neto
# ___

# %% [markdown]
# ___
#
# ## 1. Problema
#
# O Classificador Naive-Bayes, o qual se baseia no uso do teorema de Bayes, é largamente utilizado em filtros anti-spam de e-mails. O classificador permite calcular qual a probabilidade de uma mensagem ser SPAM considerando as palavras em seu conteúdo e, de forma complementar, permite calcular a probabilidade de uma mensagem ser HAM dada as palavras descritas na mensagem.
#
# Para realizar o MVP (minimum viable product) do projeto, você precisa programar uma versão do classificador que "aprende" o que é uma mensagem SPAM considerando uma base de treinamento e comparar o desempenho dos resultados com uma base de testes.

# %% [markdown]
# ___
# ## 2. Separação da base de dados em Treinamento e Teste
#
# A base de dados deve ser separada em duas partes, aleatoriamente, considerando:
#
#     75% dos dados para a parte Treinamento; e
#     25% dos dados para a parte Teste.

# %%
import pandas as pd
import os
import random

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\omarb\Downloads

# %%
dados=pd.read_excel('spamham2019(1).xlsx')
x=dados.sample(frac=1)
x=x.sample(frac=1).reset_index(drop=True)

treinamento=x.loc[:5572*0.75,:]
teste=x.loc[5572*0.75:,:]
treinamento
# Out:
#                                                   Email Class
# 0     I am literally in bed and have been up for lik...   ham
# 1      Yes:)here tv is always available in work place..   ham
# 2     When is school starting. Where will you stay. ...   ham
# 3     Great News! Call FREEFONE 08006344447 to claim...  spam
# 4     Yeah my usual guy's out of town but there're d...   ham
# 5     Hey...Great deal...Farm tour 9am to 5pm $95/pa...   ham
# 6                             Nah dub but je still buff   ham
# 7     Okay lor... Wah... like that def they wont let...   ham
# 8     So many people seems to be special at first si...   ham
# 9                Babe, I'm back ... Come back to me ...   ham
# 10    \For the most sparkling shopping breaks from 4...  spam
# 11    Got hella gas money, want to go on a grand nat...   ham
# 12                         (You didn't hear it from me)   ham
# 13    U have a Secret Admirer who is looking 2 make ...  spam
# 14    Don't b floppy... b snappy & happy! Only gay c...  spam
# 15    Show ur colours! Euro 2004 2-4-1 Offer! Get an...  spam
# 16          Haha yeah I see that now, be there in a sec   ham
# 17    Aiyah then i wait lor. Then u entertain me. He...   ham
# 18    Send ur birthdate with month and year, I will ...   ham
# 19                              Ok.. ÌÏ finishing soon?   ham
# 20                    Want to finally have lunch today?   ham
# 21      Dude im no longer a pisces. Im an aquarius now.   ham
# 22    Say this slowly.? GOD,I LOVE YOU &amp; I NEED ...   ham
# 23                            Does daddy have a bb now.   ham
# 24                Got smaller capacity one? Quite ex...   ham
# 25    Your account has been credited with 500 FREE T...  spam
# 26    Meeting u is my work. . . Tel me when shall i ...   ham
# 27    I wnt to buy a BMW car urgently..its vry urgen...   ham
# 28                I dont know oh. Hopefully this month.   ham
# 29    I wish! I don't think its gonna snow that much...   ham
# ...                                                 ...   ...
# 4150     Not yet chikku..going to room nw, i'm in bus..   ham
# 4151  Looks like you found something to do other tha...   ham
# 4152                           Oh did you charge camera   ham
# 4153           Studying. But i.ll be free next weekend.   ham
# 4154             No message..no responce..what happend?   ham
# 4155                         When are you guys leaving?   ham
# 4156                  Ofcourse I also upload some songs   ham
# 4157  For ur chance to win a å£250 cash every wk TXT...  spam
# 4158  Thanks for the Vote. Now sing along with the s...  spam
# 4159  What u talking bout early morning? It's almost...   ham
# 4160      Doing nothing, then u not having dinner w us?   ham
# 4161  K sure am in my relatives home. Sms me de. Pls:-)   ham
# 4162                     But i dint slept in afternoon.   ham
# 4163  Tell dear what happen to you. Why you talking ...   ham
# 4164  Tomorrow i am not going to theatre. . . So i c...   ham
# 4165                            I am sorry it hurt you.   ham
# 4166                       Go fool dont cheat others ok   ham
# 4167  Hey mr  and I are going to the sea view and ha...   ham
# 4168                  Sorry battery died, yeah I'm here   ham
# 4169                            U should make a fb list   ham
# 4170          see you then, we're all christmassy here!   ham
# 4171                                              Ok...   ham
# 4172                             Why are u up so early?   ham
# 4173  They just talking thats it de. They wont any o...   ham
# 4174  Of cos can lar i'm not so ba dao ok... 1 pm lo...   ham
# 4175  I know where the  &lt;#&gt;  is, I'll be there...   ham
# 4176  Did he say how fantastic I am by any chance, o...   ham
# 4177  Yar i wanted 2 scold u yest but late already.....   ham
# 4178                          Yes see ya not on the dot   ham
# 4179             How are you. Wish you a great semester   ham
#
# [4180 rows x 2 columns]

# %%
lista_treinamento = treinamento["Email"].tolist()
lista_treinamento = str(lista_treinamento)
lista_treinamento = lista_treinamento.replace(",","")
lista_treinamento = lista_treinamento.replace("'","")
lista_treinamento = lista_treinamento.replace("[","")
lista_treinamento = lista_treinamento.replace("]","")
lista_treinamento = lista_treinamento.replace(":","")
lista_treinamento = lista_treinamento.replace(";","")
lista_treinamento = lista_treinamento.replace("_","")
#lista_treinamento = lista_treinamento.replace("\","")
lista_treinamento = lista_treinamento.replace("$","")
lista_treinamento = lista_treinamento.replace("&","")
lista_treinamento = lista_treinamento.replace("(","")
lista_treinamento = lista_treinamento.replace(")","")
lista_treinamento = lista_treinamento.replace(".","")
lista_treinamento = lista_treinamento.replace("#","")                                              
lista_treinamento = lista_treinamento.split()
lista_treinamento
# Out:
# ['I',
#  'am',
#  'literally',
#  'in',
#  'bed',
#  'and',
#  'have',
#  'been',
#  'up',
#  'for',
#  'like',
#  'ltgt',
#  'hours',
#  'Yeshere',
#  'tv',
#  'is',
#  'always',
#  'available',
#  'in',
#  'work',
#  'place',
#  '"When',
#  'is',
#  'school',
#  'starting',
#  'Where',
#  'will',
#  'you',
#  'stay',
#  'Whats',
#  'the',
#  'weather',
#  'like',
#  'And',
#  'the',
#  'food',
#  'Do',
#  'you',
#  'have',
#  'a',
#  'social',
#  'support',
#  'system',
#  'like',
#  'friends',
#  'in',
#  'the',
#  'school',
#  'All',
#  'these',
#  'things',
#  'are',
#  'important"',
#  'Great',
#  'News!',
#  'Call',
#  'FREEFONE',
#  '08006344447',
#  'to',
#  'claim',
#  'your',
#  'guaranteed',
#  'å£1000',
#  'CASH',
#  'or',
#  'å£2000',
#  'gift',
#  'Speak',
#  'to',
#  'a',
#  'live',
#  'operator',
#  'NOW!',
#  '"Yeah',
#  'my',
#  'usual',
#  'guys',
#  'out',
#  'of',
#  'town',
#  'but',
#  'therere',
#  'definitely',
#  'people',
#  'around',
#  'I',
#  'know"',
#  'HeyGreat',
#  'dealFarm',
#  'tour',
#  '9am',
#  'to',
#  '5pm',
#  '95/pax',
#  '50',
#  'deposit',
#  'by',
#  '16',
#  'May',
#  'Nah',
#  'dub',
#  'but',
#  'je',
#  'still',
#  'buff',
#  'Okay',
#  'lor',
#  'Wah',
#  'like',
#  'that',
#  'def',
#  'they',
#  'wont',
#  'let',
#  'us',
#  'go',
#  'Haha',
#  'What',
#  'did',
#  'they',
#  'say',
#  'in',
#  'the',
#  'terms',
#  'and',
#  'conditions?',
#  'So',
#  'many',
#  'people',
#  'seems',
#  'to',
#  'be',
#  'special',
#  'at',
#  'first',
#  'sight',
#  'But',
#  'only',
#  'very',
#  'few',
#  'will',
#  'remain',
#  'special',
#  'to',
#  'you',
#  'till',
#  'your',
#  'last',
#  'sight',
#  'Maintain',
#  'them',
#  'till',
#  'life',
#  'ends',
#  'take',
#  'cr',
#  'da',
#  '"Babe',
#  'Im',
#  'back',
#  'Come',
#  'back',
#  'to',
#  'me',
#  '"',
#  '\\\\For',
#  'the',
#  'most',
#  'sparkling',
#  'shopping',
#  'breaks',
#  'from',
#  '45',
#  'per',
#  'person',
#  'call',
#  '0121',
#  '2025050',
#  'or',
#  'visit',
#  'wwwshortbreaksorguk\\\\""',
#  'Got',
#  'hella',
#  'gas',
#  'money',
#  'want',
#  'to',
#  'go',
#  'on',
#  'a',
#  'grand',
#  'nature',
#  'adventure',
#  'with',
#  'galileo',
#  'in',
#  'a',
#  'little',
#  'bit?',
#  '"You',
#  'didnt',
#  'hear',
#  'it',
#  'from',
#  'me"',
#  'U',
#  'have',
#  'a',
#  'Secret',
#  'Admirer',
#  'who',
#  'is',
#  'looking',
#  '2',
#  'make',
#  'contact',
#  'with',
#  'U-find',
#  'out',
#  'who',
#  'they',
#  'R*reveal',
#  'who',
#  'thinks',
#  'UR',
#  'so',
#  'special-call',
#  'on',
#  '09065171142-stopsms-08718727870150ppm',
#  '"Dont',
#  'b',
#  'floppy',
#  'b',
#  'snappy',
#  'happy!',
#  'Only',
#  'gay',
#  'chat',
#  'service',
#  'with',
#  'photo',
#  'upload',
#  'call',
#  '08718730666',
#  '10p/min',
#  '2',
#  'stop',
#  'our',
#  'texts',
#  'call',
#  '08712460324"',
#  'Show',
#  'ur',
#  'colours!',
#  'Euro',
#  '2004',
#  '2-4-1',
#  'Offer!',
#  'Get',
#  'an',
#  'England',
#  'Flag',
#  '3Lions',
#  'tone',
#  'on',
#  'ur',
#  'phone!',
#  'Click',
#  'on',
#  'the',
#  'following',
#  'service',
#  'message',
#  'for',
#  'info!',
#  'Haha',
#  'yeah',
#  'I',
#  'see',
#  'that',
#  'now',
#  'be',
#  'there',
#  'in',
#  'a',
#  'sec',
#  'Aiyah',
#  'then',
#  'i',
#  'wait',
#  'lor',
#  'Then',
#  'u',
#  'entertain',
#  'me',
#  'Hee',
#  '"Send',
#  'ur',
#  'birthdate',
#  'with',
#  'month',
#  'and',
#  'year',
#  'I',
#  'will',
#  'tel',
#  'u',
#  'ur',
#  'LIFE',
#  'PARTNERS',
#  'name',
#  'and',
#  'the',
#  'method',
#  'of',
#  'calculation',
#  'Reply',
#  'must"',
#  'Ok',
#  'ÌÏ',
#  'finishing',
#  'soon?',
#  'Want',
#  'to',
#  'finally',
#  'have',
#  'lunch',
#  'today?',
#  'Dude',
#  'im',
#  'no',
#  'longer',
#  'a',
#  'pisces',
#  'Im',
#  'an',
#  'aquarius',
#  'now',
#  'Say',
#  'this',
#  'slowly?',
#  'GODI',
#  'LOVE',
#  'YOU',
#  'amp',
#  'I',
#  'NEED',
#  'YOUCLEAN',
#  'MY',
#  'HEART',
#  'WITH',
#  'YOUR',
#  'BLOODSend',
#  'this',
#  'to',
#  'Ten',
#  'special',
#  'people',
#  'amp',
#  'u',
#  'c',
#  'miracle',
#  'tomorrow',
#  'do',
#  'itplspls',
#  'do',
#  'it',
#  'Does',
#  'daddy',
#  'have',
#  'a',
#  'bb',
#  'now',
#  'Got',
#  'smaller',
#  'capacity',
#  'one?',
#  'Quite',
#  'ex',
#  'Your',
#  'account',
#  'has',
#  'been',
#  'credited',
#  'with',
#  '500',
#  'FREE',
#  'Text',
#  'Messages',
#  'To',
#  'activate',
#  'just',
#  'txt',
#  'the',
#  'word',
#  'CREDIT',
#  'to',
#  'No',
#  '80488',
#  'TCs',
#  'www80488biz',
#  'Meeting',
#  'u',
#  'is',
#  'my',
#  'work',
#  'Tel',
#  'me',
#  'when',
#  'shall',
#  'i',
#  'do',
#  'my',
#  'work',
#  'tomorrow',
#  'I',
#  'wnt',
#  'to',
#  'buy',
#  'a',
#  'BMW',
#  'car',
#  'urgentlyits',
#  'vry',
#  'urgentbut',
#  'hv',
#  'a',
#  'shortage',
#  'of',
#  'ltgt',
#  'Lacsthere',
#  'is',
#  'no',
#  'source',
#  'to',
#  'arng',
#  'dis',
#  'amt',
#  'ltgt',
#  'lacsthats',
#  'my',
#  'prob',
#  'I',
#  'dont',
#  'know',
#  'oh',
#  'Hopefully',
#  'this',
#  'month',
#  '"I',
#  'wish!',
#  'I',
#  'dont',
#  'think',
#  'its',
#  'gonna',
#  'snow',
#  'that',
#  'much',
#  'But',
#  'it',
#  'will',
#  'be',
#  'more',
#  'than',
#  'those',
#  'flurries',
#  'we',
#  'usually',
#  'get',
#  'that',
#  'melt',
#  'before',
#  'they',
#  'hit',
#  'the',
#  'ground',
#  'Eek!',
#  'We',
#  'havent',
#  'had',
#  'snow',
#  'since',
#  'ltgt',
#  'before',
#  'I',
#  'was',
#  'even',
#  'born!"',
#  'it',
#  'to',
#  '80488',
#  'Your',
#  '500',
#  'free',
#  'text',
#  'messages',
#  'are',
#  'valid',
#  'until',
#  '31',
#  'December',
#  '2005',
#  'You',
#  'lifted',
#  'my',
#  'hopes',
#  'with',
#  'the',
#  'offer',
#  'of',
#  'money',
#  'I',
#  'am',
#  'in',
#  'need',
#  'Especially',
#  'when',
#  'the',
#  'end',
#  'of',
#  'the',
#  'month',
#  'approaches',
#  'and',
#  'it',
#  'hurts',
#  'my',
#  'studying',
#  'Anyways',
#  'have',
#  'a',
#  'gr8',
#  'weekend',
#  '"Noice',
#  'Text',
#  'me',
#  'when',
#  'youre',
#  'here"',
#  'Please',
#  'CALL',
#  '08712402902',
#  'immediately',
#  'as',
#  'there',
#  'is',
#  'an',
#  'urgent',
#  'message',
#  'waiting',
#  'for',
#  'you',
#  '"Sorry',
#  'Ill',
#  'call',
#  'later"',
#  '"alright',
#  'Ill',
#  'make',
#  'sure',
#  'the',
#  'car',
#  'is',
#  'back',
#  'tonight"',
#  '"Also',
#  'remember',
#  'the',
#  'beads',
#  'dont',
#  'come',
#  'off',
#  'Ever"',
#  'Beautiful',
#  'Truth',
#  'against',
#  'Gravity',
#  'Read',
#  'carefully',
#  '\\\\Our',
#  'heart',
#  'feels',
#  'light',
#  'when',
#  'someone',
#  'is',
#  'in',
#  'it',
#  'But',
#  'it',
#  'feels',
#  'very',
#  'heavy',
#  'when',
#  'someone',
#  'leaves',
#  'it\\\\"',
#  'GOODMORNING"',
#  'No',
#  '1',
#  'Nokia',
#  'Tone',
#  '4',
#  'ur',
#  'mob',
#  'every',
#  'week!',
#  'Just',
#  'txt',
#  'NOK',
#  'to',
#  '87021',
#  '1st',
#  'Tone',
#  'FREE',
#  '!',
#  'so',
#  'get',
#  'txtin',
#  'now',
#  'and',
#  'tell',
#  'ur',
#  'friends',
#  '150p/tone',
#  '16',
#  'reply',
#  'HL',
#  '4info',
#  '"Yeah',
#  'jays',
#  'sort',
#  'of',
#  'a',
#  'fucking',
#  'retard"',
#  'GWR',
#  'You',
#  'are',
#  'awarded',
#  'a',
#  'SiPix',
#  'Digital',
#  'Camera!',
#  'call',
#  '09061221061',
#  'from',
#  'landline',
#  'Delivery',
#  'within',
#  '28days',
#  'T',
#  'Cs',
#  'Box177',
#  'M221BP',
#  '2yr',
#  'warranty',
#  '150ppm',
#  '16',
#  'p',
#  'på£399',
#  'Have',
#  'you',
#  'been',
#  'practising',
#  'your',
#  'curtsey?',
#  '\\\\ER',
#  'What',
#  'makes',
#  'you',
#  'most',
#  'happy?',
#  'A',
#  'lot',
#  'of',
#  'this',
#  'sickness',
#  'thing',
#  'going',
#  'round',
#  'Take',
#  'it',
#  'easy',
#  'Hope',
#  'u',
#  'feel',
#  'better',
#  'soon',
#  'Lol',
#  '"Thats',
#  'very',
#  'rude',
#  'you',
#  'on',
#  'campus?"',
#  'Nimbomsons',
#  'Yep',
#  'phone',
#  'knows',
#  'that',
#  'one',
#  'Obviously',
#  'cos',
#  'thats',
#  'a',
#  'real',
#  'word',
#  '"ltgt',
#  'is',
#  'fast',
#  'approaching',
#  'So',
#  'Wish',
#  'u',
#  'a',
#  'very',
#  'Happy',
#  'New',
#  'Year',
#  'Happy',
#  'Sankranti',
#  'Happy',
#  'republic',
#  'day',
#  'Happy',
#  'Valentines',
#  'Day',
#  'Happy',
#  'Shivratri',
#  'Happy',
#  'Ugadi',
#  'Happy',
#  'Fools',
#  'day',
#  'Happy',
#  'May',
#  'Day',
#  'Happy',
#  'Independence',
#  'Day',
#  'Happy',
#  'FriendshipMotherFatherTeachersChildrens',
#  'Day',
#  'amp',
#  'HAPPY',
#  'BIRTHDAY',
#  '4',
#  'U',
#  'Happy',
#  'Ganesh',
#  'festival',
#  'Happy',
#  'Dasara',
#  'Happy',
#  'Diwali',
#  'Happy',
#  'Christmas',
#  'ltgt',
#  'Good',
#  'Mornings',
#  'Afternoons',
#  'Evenings',
#  'Nights',
#  'RememberI',
#  'AM',
#  'the',
#  'first',
#  'to',
#  'WISHING',
#  'U',
#  'ALL',
#  'THESEyours',
#  'Raj"',
#  'Wishing',
#  'you',
#  'a',
#  'beautiful',
#  'day',
#  'Each',
#  'moment',
#  'revealing',
#  'even',
#  'more',
#  'things',
#  'to',
#  'keep',
#  'you',
#  'smiling',
#  'Do',
#  'enjoy',
#  'it',
#  'Oh',
#  'that',
#  'was',
#  'a',
#  'forwarded',
#  'message',
#  'I',
#  'thought',
#  'you',
#  'send',
#  'that',
#  'to',
#  'me',
#  'Fuck',
#  'cedar',
#  'key',
#  'and',
#  'fuck',
#  'her',
#  'come',
#  'over',
#  'anyway',
#  'tho',
#  '"U',
#  'wake',
#  'up',
#  'already?',
#  'Thanx',
#  '4',
#  'e',
#  'tau',
#  'sar',
#  'piah',
#  'its',
#  'quite',
#  'nice"',
#  'I',
#  'dont',
#  'knw',
#  'pa',
#  'i',
#  'just',
#  'drink',
#  'milk',
#  'Sounds',
#  'like',
#  'something',
#  'that',
#  'someone',
#  'testing',
#  'me',
#  'would',
#  'sayy',
#  'Then',
#  'Ì',
#  'wait',
#  '4',
#  'me',
#  'at',
#  'bus',
#  'stop',
#  'aft',
#  'ur',
#  'lect',
#  'lar',
#  'If',
#  'i',
#  'dun',
#  'c',
#  'Ì',
#  'then',
#  'i',
#  'go',
#  'get',
#  'my',
#  'car',
#  'then',
#  'come',
#  'back',
#  'n',
#  'pick',
#  'Ì',
#  'Have',
#  'you',
#  'started',
#  'in',
#  'skye',
#  'How',
#  'do',
#  'you',
#  'plan',
#  'to',
#  'manage',
#  'that',
#  'You',
#  'will',
#  'recieve',
#  'your',
#  'tone',
#  'within',
#  'the',
#  'next',
#  '24hrs',
#  'For',
#  'Terms',
#  'and',
#  'conditions',
#  'please',
#  'see',
#  'Channel',
#  'U',
#  'Teletext',
#  'Pg',
#  '750',
#  'URGENT!!',
#  'Your',
#  '4*',
#  'Costa',
#  'Del',
#  'Sol',
#  'Holiday',
#  'or',
#  'å£5000',
#  'await',
#  'collection',
#  'Call',
#  '09050090044',
#  'Now',
#  'toClaim',
#  'SAE',
#  'TC',
#  's',
#  'POBox334',
#  'Stockport',
#  'SK38xh',
#  'Costå£150/pm',
#  'Max10mins',
#  'Thanks',
#  'for',
#  'your',
#  'ringtone',
#  'order',
#  'ref',
#  'number',
#  'K718',
#  'Your',
#  'mobile',
#  'will',
#  'be',
#  'charged',
#  'å£450',
#  'Should',
#  'your',
#  'tone',
#  'not',
#  'arrive',
#  'please',
#  'call',
#  'customer',
#  'services',
#  'on',
#  '09065069120',
#  '"Im',
#  'home',
#  'Doc',
#  'gave',
#  'me',
#  'pain',
#  'meds',
#  'says',
#  'everything',
#  'is',
#  'fine"',
#  '"',
#  'hows',
#  'things?',
#  'Just',
#  'a',
#  'quick',
#  'question"',
#  'URGENT!',
#  'Your',
#  'Mobile',
#  'No',
#  '07808726822',
#  'was',
#  'awarded',
#  'a',
#  'å£2000',
#  'Bonus',
#  'Caller',
#  'Prize',
#  'on',
#  '02/09/03!',
#  'This',
#  'is',
#  'our',
#  '2nd',
#  'attempt',
#  'to',
#  'contact',
#  'YOU!',
#  'Call',
#  '0871-872-9758',
#  'BOX95QU',
#  'Hope',
#  'you',
#  ...]

# %% [markdown]
# ___
# ## 3. Classificador Naive-Bayes

# %% [markdown]
# ___
# ## 4. Qualidade do Classificador alterando a base de treinamento
